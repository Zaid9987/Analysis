# %%
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Pandas_Operation / Visualization using Matplotlib,Seaborn: 
'''
Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks.
It is built on top of another package named Numpy, which provides support for multi-dimensional arrays.
'''
'''
Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. 
Matplotlib makes easy things easy and hard things possible.
'''
'''
Seaborn is a library that uses Matplotlib underneath to plot graphs. 
It will be used to visualize random distributions.
'''
# Out:
# '\nSeaborn is a library that uses Matplotlib underneath to plot graphs. \nIt will be used to visualize random distributions.\n'

# %%
# read function is used to open files. read_table is a universal command used to access any kind of file.

df = pd.read_csv("gas_prices.csv")
df
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# 13  2003       2.19    1.99    4.35     4.59   4.53   3.47    2.04
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 0          2.05  2.82  1.16
# 1          2.49  3.01  1.14
# 2          2.65  3.06  1.13
# 3          2.88  2.84  1.11
# 4          2.87  2.99  1.11
# 5          2.94  3.21  1.15
# 6          3.18  3.34  1.23
# 7          3.34  3.83  1.23
# 8          3.04  4.06  1.06
# 9          3.80  4.29  1.17
# 10         4.18  4.58  1.51
# 11         3.76  4.13  1.46
# 12         3.84  4.16  1.36
# 13         4.11  4.70  1.59
# 14         4.51  5.56  1.88
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27

# %%
df.info() #Used to access information of table, such as column names,datatypes,indexes,memory usage,etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         19 non-null     int64
#  1   Australia    18 non-null     float64
#  2   Canada       19 non-null     float64
#  3   France       19 non-null     float64
#  4   Germany      19 non-null     float64
#  5   Italy        19 non-null     float64
#  6   Japan        19 non-null     float64
#  7   Mexico       19 non-null     float64
#  8   South Korea  19 non-null     float64
#  9   UK           19 non-null     float64
#  10  USA          19 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1.8 KB

# %%
df.describe() #The describe() method returns description of the data in the DataFrame.
              #If the DataFrame contains numerical data, the description contains these information for each column:
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# min     2.820000   1.000000     2.050000   2.820000   1.060000
# 25%     3.270000   1.475000     2.910000   3.135000   1.145000
# 50%     3.640000   1.790000     3.760000   4.130000   1.230000
# 75%     4.320000   2.210000     4.345000   5.130000   1.735000
# max     5.740000   2.450000     6.210000   7.420000   3.270000

# %%
df.dtypes #gives access to data-types of columns.
# Out:
# Year             int64
# Australia      float64
# Canada         float64
# France         float64
# Germany        float64
# Italy          float64
# Japan          float64
# Mexico         float64
# South Korea    float64
# UK             float64
# USA            float64
# dtype: object

# %%
df.columns #shows name of columns
# Out:
# Index(['Year', 'Australia', 'Canada', 'France', 'Germany', 'Italy', 'Japan',
#        'Mexico', 'South Korea', 'UK', 'USA'],
#       dtype='object')

# %%
df.shape #give shape of the dataset, i.e. number of rows and columns.
# Out:
# (19, 11)

# %%
df.head() #gives access to first 5 rows. starting from index 0.
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
# we can access any no. of columns using head function.

df.head(3)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16     1.0
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46     1.3
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58     1.5
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13

# %%
df.tail() # gives indexing from backwards.
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
#
# 1          2.49  3.01  1.14          4.15
# 2          2.65  3.06  1.13          4.19
# 3          2.88  2.84  1.11          3.95
# 4          2.87  2.99  1.11          4.10
# 5          2.94  3.21  1.15          4.36
# 6          3.18  3.34  1.23          4.57
# 7          3.34  3.83  1.23          5.06
# 8          3.04  4.06  1.06          5.12
# 9          3.80  4.29  1.17          5.46
# 10         4.18  4.58  1.51          6.09
# 11         3.76  4.13  1.46          5.59
# 12         3.84  4.16  1.36          5.52
# 13         4.11  4.70  1.59          6.29
# 14         4.51  5.56  1.88          7.44
# 15         5.28  5.97  2.30          8.27
# 16         5.92  6.36  2.59          8.95
# 17         6.21  7.13  2.80          9.93
# 18         5.83  7.42  3.27         10.69

# %%
# To access particular column we use:

df["Year"]
# Out:
# 0     1990
# 1     1991
# 2     1992
# 3     1993
# 4     1994
# 5     1995
# 6     1996
# 7     1997
# 8     1998
# 9     1999
# 10    2000
# 11    2001
# 12    2002
# 13    2003
# 14    2004
# 15    2005
# 16    2006
# 17    2007
# 18    2008
# Name: Year, dtype: int64

# %%
# accessing columns as per user needs:

df[["Year","UK","USA"]][0:6]
# Out:
#    Year    UK   USA
# 0  1990  2.82  1.16
# 1  1991  3.01  1.14
# 2  1992  3.06  1.13
# 3  1993  2.84  1.11
# 4  1994  2.99  1.11
# 5  1995  3.21  1.15

# %%
# can also access data with the help of indexing and slicing:

df["Year"][:10] #Shows row upto index 9 starting from index 0.
# Out:
# 0    1990
# 1    1991
# 2    1992
# 3    1993
# 4    1994
# 5    1995
# 6    1996
# 7    1997
# 8    1998
# 9    1999
# Name: Year, dtype: int64

# %%
df["Year"][10:13] # access index from 101 and 105
# Out:
# 10    2000
# 11    2001
# 12    2002
# Name: Year, dtype: int64

# %%
# changes values for column Australia from index 0 to 6 

df["Australia"][0:5] = [1,2,3,4,5]
df
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990       1.00    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       2.00    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       3.00    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       4.00    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       5.00    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# 13  2003       2.19    1.99    4.35     4.59   4.53   3.47    2.04
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA  Total_UK_USA
# 0          2.05  2.82  1.16          3.98
# 1          2.49  3.01  1.14          4.15
# 2          2.65  3.06  1.13          4.19
# 3          2.88  2.84  1.11          3.95
# 4          2.87  2.99  1.11          4.10
# 5          2.94  3.21  1.15          4.36
# 6          3.18  3.34  1.23          4.57
# 7          3.34  3.83  1.23          5.06
# 8          3.04  4.06  1.06          5.12
# 9          3.80  4.29  1.17          5.46
# 10         4.18  4.58  1.51          6.09
# 11         3.76  4.13  1.46          5.59
# 12         3.84  4.16  1.36          5.52
# 13         4.11  4.70  1.59          6.29
# 14         4.51  5.56  1.88          7.44
# 15         5.28  5.97  2.30          8.27
# 16         5.92  6.36  2.59          8.95
# 17         6.21  7.13  2.80          9.93
# 18         5.83  7.42  3.27         10.69

# %%
# for rows and columns slicing we use loc and iloc:
# iloc[row slicing, column slicing]

df.iloc[0:3,1:4]
# Out:
#    Australia  Canada  France
# 0        1.0    1.87    3.63
# 1        2.0    1.92    3.45
# 2        3.0    1.73    3.56

# %%
# loc take the particular name of the index
# iloc takes the default number of index.

df.loc[0:3]
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        1.0    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991        2.0    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992        3.0    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993        4.0    1.57    3.41     3.07   3.68   4.16    1.56
#
#    South Korea    UK   USA  Total_UK_USA
# 0         2.05  2.82  1.16          3.98
# 1         2.49  3.01  1.14          4.15
# 2         2.65  3.06  1.13          4.19
# 3         2.88  2.84  1.11          3.95

# %%
# Transpose index and columns:
# make (rows your columns) and (columns to rows)

df.T
# Out:
#                    0        1        2        3        4        5        6   \
# Year          1990.00  1991.00  1992.00  1993.00  1994.00  1995.00  1996.00
# Australia        1.00     2.00     3.00     4.00     5.00     1.95     2.12
# Canada           1.87     1.92     1.73     1.57     1.45     1.53     1.61
# France           3.63     3.45     3.56     3.41     3.59     4.26     4.41
# Germany          2.65     2.90     3.27     3.07     3.52     3.96     3.94
# Italy            4.59     4.50     4.53     3.68     3.70     4.00     4.39
# Japan            3.16     3.46     3.58     4.16     4.36     4.43     3.64
# Mexico           1.00     1.30     1.50     1.56     1.48     1.11     1.25
# South Korea      2.05     2.49     2.65     2.88     2.87     2.94     3.18
# UK               2.82     3.01     3.06     2.84     2.99     3.21     3.34
# USA              1.16     1.14     1.13     1.11     1.11     1.15     1.23
# Total_UK_USA     3.98     4.15     4.19     3.95     4.10     4.36     4.57
#
#                    7        8        9        10       11       12       13  \
# Year          1997.00  1998.00  1999.00  2000.00  2001.00  2002.00  2003.00
# Australia        2.05     1.63     1.72     1.94     1.71     1.76     2.19
# Canada           1.62     1.38     1.52     1.86     1.72     1.69     1.99
# France           4.00     3.87     3.85     3.80     3.51     3.62     4.35
# Germany          3.53     3.34     3.42     3.45     3.40     3.67     4.59
# Italy            4.07     3.84     3.87     3.77     3.57     3.74     4.53
# 5          2.94  3.21  1.15          4.36
# 4          2.87  2.99  1.11          4.10
# 3          2.88  2.84  1.11          3.95
# 2          2.65  3.06  1.13          4.19
# 1          2.49  3.01  1.14          4.15
# 0          2.05  2.82  1.16          3.98

# %%
# making copy of a dataset;
# [new-dataset = current-dataset.copy()]

newdf = df.copy()

# %%
newdf
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990       1.00    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       2.00    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       3.00    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       4.00    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       5.00    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# 13  2003       2.19    1.99    4.35     4.59   4.53   3.47    2.04
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA  Total_UK_USA
# 0          2.05  2.82  1.16          3.98
# 1          2.49  3.01  1.14          4.15
# 2          2.65  3.06  1.13          4.19
# 3          2.88  2.84  1.11          3.95
# 4          2.87  2.99  1.11          4.10
# 5          2.94  3.21  1.15          4.36
# 6          3.18  3.34  1.23          4.57
# 7          3.34  3.83  1.23          5.06
# 8          3.04  4.06  1.06          5.12
# 9          3.80  4.29  1.17          5.46
# 10         4.18  4.58  1.51          6.09
# 11         3.76  4.13  1.46          5.59
# 12         3.84  4.16  1.36          5.52
# 13         4.11  4.70  1.59          6.29
# 14         4.51  5.56  1.88          7.44
# 15         5.28  5.97  2.30          8.27
# 16         5.92  6.36  2.59          8.95
# 17         6.21  7.13  2.80          9.93
# 18         5.83  7.42  3.27         10.69

# %%
# rename is used to change name of the column.
# inplace=True is used to mark changes permanently.

df.rename(columns = {"Canada":"India"},inplace=True)
df
# Out:
#     Year  Australia  India  France  Germany  Italy  Japan  Mexico  \
# 0   1990       1.00   1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       2.00   1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       3.00   1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       4.00   1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       5.00   1.45    3.59     3.52   3.70   4.36    1.48
# 16  2006       3.54   3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85   3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45   4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA  Total_UK_USA
# 0          2.05  2.82  1.16          3.98
# 1          2.49  3.01  1.14          4.15
# 2          2.65  3.06  1.13          4.19
# 3          2.88  2.84  1.11          3.95
# 4          2.87  2.99  1.11          4.10
# 5          2.94  3.21  1.15          4.36
# 6          3.18  3.34  1.23          4.57
# 7          3.34  3.83  1.23          5.06
# 8          3.04  4.06  1.06          5.12
# 9          3.80  4.29  1.17          5.46
# 10         4.18  4.58  1.51          6.09
# 11         3.76  4.13  1.46          5.59
# 12         3.84  4.16  1.36          5.52
# 13         4.11  4.70  1.59          6.29
# 14         4.51  5.56  1.88          7.44
# 15         5.28  5.97  2.30          8.27
# 16         5.92  6.36  2.59          8.95
# 17         6.21  7.13  2.80          9.93
# 18         5.83  7.42  3.27         10.69

# %%
# finds the mean of the column.

df["Year"].mean()
# Out:
# 1999.0

# %%
# finds median of the column.

df["Year"].median()
# Out:
# 1999.0

# %%
df["India"].hist(figsize=(10,5),color="green")

# hist function returns the distribution of data on a graph.
# figsize is used to give size of a graph.
# color function returns the data in defined color.
# Out:
# <AxesSubplot:>

# %%
# to plot multiple graph:

df[["Australia","India"]].hist(figsize=(15,5),color="blue")
plt.tight_layout() #automatically adjusts subplot parameters so that the subplot(s) fits in to the figure area.
plt.show()         #use to display the all the figures.
# Out:
# 'OBSERVATIONS:\nHighest number of customers range between age 44-50.\nLowest number of customer range between age 67-73.\n\nDependent count 3 is high.\n'

# %%
# Line-Plot: used to access plot in lines.

x = np.arange(10) # to plot number range till 10
y = np.sqrt(x)    # return the non-negative square-root of an array
sns.lineplot(x,y) # for plotting lineplot in x and y axis
plt.grid(True)    # grid function marks horizontal and vertical line on graph for better understanding.
plt.show()

# %%
# dist-plot: used to access graph in line and histogram format.

sns.distplot(df["Germany"])
plt.grid()
plt.show()
# Out:
# 'OBSERVATION:\nLine on the upper side of the histogram shows density between 0.04-0.05.\n'

# %%
# count-plot: countplot() method is used to Show the counts of observations in each categorical bin using bars.

sns.countplot(data=df,x='India',hue='Year') # hue parameter take column name for colour encoding.
plt.grid()
plt.show()
# Out:
# 'OBSERVATION:\nThe highest education-level in both male and female is graduation.\nHigh-school education-level in both male and female stands on 2nd number.\nLowest education-level is doctorate in both.\n'

# %%
# sub-plot is used to divide and plot multiple columns on the graph.
 
plt.subplot(2,2,1) # plotting graph on position 1
df['India'].value_counts().plot(figsize=(8,8),kind='bar',color='blue') # kind="bar" is used to plot bar type graph.
plt.title("India Diagram") # plt.title used to give diagram heading
plt.ylabel("No. of sales")    # ylabel is used to label no. of customers on y-axis.
plt.xlabel("India")        # xlabel is used to label customer age on x-axis.
plt.grid()

plt.subplot(2,2,2) # plotting graph on position 2
df['Australia'].value_counts().plot(figsize=(8,8),kind='bar',color='red')
plt.title("Australia Diagram")
plt.ylabel("No. of sales")
plt.xlabel("Australia")
plt.grid()

plt.subplot(2,2,3) # plotting graph on position 3
df['Germany'].value_counts().plot(figsize=(8,8),kind='bar',color='purple')
plt.title("Germany Diagram")
plt.ylabel("No. of sales")
plt.xlabel("Germany")
plt.grid()

plt.subplot(2,2,4) # plotting graph on position 4
df['UK'].value_counts().plot(figsize=(8,8),kind='bar',color='yellow')
plt.title("UK Diagram")
plt.ylabel("No. of sales")
plt.xlabel("UK")
plt.grid()

plt.tight_layout()
plt.show()

# %%
df.corr() #shows co-relation between different columns.
# Out:
#                   Year  Australia     India    France   Germany     Italy  \
# Year          1.000000   0.296837  0.743494  0.783013  0.850042  0.650927
# Australia     0.296837   1.000000  0.522073  0.515511  0.566238  0.502998
# India         0.743494   0.522073  1.000000  0.945870  0.935075  0.970192
# France        0.783013   0.515511  0.945870  1.000000  0.981924  0.951436
# Germany       0.850042   0.566238  0.935075  0.981924  1.000000  0.920420
# Italy         0.650927   0.502998  0.970192  0.951436  0.920420  1.000000
# Japan         0.450672   0.797204  0.743415  0.774489  0.777531  0.731602
# Mexico        0.916437   0.363349  0.691224  0.625543  0.721284  0.547230
# South Korea   0.949350   0.445821  0.865753  0.870020  0.913963  0.776858
# UK            0.940524   0.396986  0.904195  0.913211  0.937122  0.843946
# USA           0.841465   0.524135  0.983083  0.958066  0.965215  0.932612
# Total_UK_USA  0.918967   0.441343  0.938558  0.936901  0.955758  0.880776
#
#                  Japan    Mexico  South Korea        UK       USA  \
# Year          0.450672  0.916437     0.949350  0.940524  0.841465
# Australia     0.797204  0.363349     0.445821  0.396986  0.524135
# India         0.743415  0.691224     0.865753  0.904195  0.983083
# France        0.774489  0.625543     0.870020  0.913211  0.958066
# Germany       0.777531  0.721284     0.913963  0.937122  0.965215
# Italy         0.731602  0.547230     0.776858  0.843946  0.932612
# Japan         1.000000  0.391669     0.595976  0.585465  0.742593
# Mexico        0.391669  1.000000     0.886279  0.851356  0.777122
# South Korea   0.595976  0.886279     1.000000  0.973141  0.928654
# UK            0.585465  0.851356     0.973141  1.000000  0.952380
# USA           0.742593  0.777122     0.928654  0.952380  1.000000
# Total_UK_USA  0.641267  0.836726     0.969189  0.995336  0.977353
#
#               Total_UK_USA
# Year              0.918967
# Australia         0.441343
# India             0.938558
# France            0.936901
# Germany           0.955758
# Italy             0.880776
# Japan             0.641267
# Mexico            0.836726
# South Korea       0.969189
# UK                0.995336
# USA               0.977353
# Total_UK_USA      1.000000

# %%
# heatmap data visualization is a method of graphically representing numerical data where the value of each data point is indicated using colors.

plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap='Blues') # annot=True to access values in each cell, cmap is used to give color code.
plt.show()

# %%
#scatterplot : A scatterplot is a type of data display that shows the relationship between two numerical variables in dot.

plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x='Year',y='India')
plt.grid()
plt.show()
# Out:
# 'OBSERVATION:\nhere, income category is equally distributed with education level\n'

# %%
#Pair-plot: The Seaborn Pairplot allows us to plot pairwise relationships between variables within a dataset.

plt.figure(figsize=(10,10))
sns.pairplot(df[['India','Australia','France']],diag_kind='hist')
plt.show()
